# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.datasets import load_boston
#
# File ~\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:157, in __getattr__(name)
#     108 if name == "load_boston":
#     109     msg = textwrap.dedent("""
#     110         `load_boston` has been removed from scikit-learn since version 1.2.
#     111
#    (...)
#     155         <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
#     156         """)
# --> 157     raise ImportError(msg)
#     158 try:
#     159     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# ...

# %%
pip install scikit-learn
# Out:
#   Cell In[6], line 1
#     pip install scikit-learn
#         ^
# SyntaxError: invalid syntax

# %%
from sklearn.datasets import load_boston
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sklearn.datasets import load_boston
#
# File ~\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:157, in __getattr__(name)
#     108 if name == "load_boston":
#     109     msg = textwrap.dedent("""
#     110         `load_boston` has been removed from scikit-learn since version 1.2.
#     111
#    (...)
#     155         <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
#     156         """)
# --> 157     raise ImportError(msg)
#     158 try:
#     159     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# ...

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
sklearn.datasets.load_boston
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sklearn.datasets.load_boston
#
# File ~\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:157, in __getattr__(name)
#     108 if name == "load_boston":
#     109     msg = textwrap.dedent("""
#     110         `load_boston` has been removed from scikit-learn since version 1.2.
#     111
#    (...)
#     155         <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
#     156         """)
# --> 157     raise ImportError(msg)
#     158 try:
#     159     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# ...

# %%
import warnings
>>> from sklearn.datasets import load_boston
>>> with warnings.catch_warnings():
...     # You should probably not use this dataset.
...     warnings.filterwarnings("ignore")
...     X, y = load_boston(return_X_y=True)
>>> print(X.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 import warnings
# ----> 2 from sklearn.datasets import load_boston
#       3 with warnings.catch_warnings():
#       4     # You should probably not use this dataset.
#       5     warnings.filterwarnings("ignore")
#
# File ~\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:157, in __getattr__(name)
#     108 if name == "load_boston":
#     109     msg = textwrap.dedent("""
#     110         `load_boston` has been removed from scikit-learn since version 1.2.
#     111
#    (...)
#     155         <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
#     156         """)
# --> 157     raise ImportError(msg)
#     158 try:
#     159     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
# ...

# %%
from sklearn.datasets import fetch_openml

# %%
from sklearn.datasets import fetch_openml

# Fetch the Boston housing dataset
boston = fetch_openml('boston', version=1)

# Print the description of the dataset
print(boston.DESCR)

# Access the features and target variable
X = boston.data  # Features
y = boston.target  # Target variable

# Print the shape of the features and target variable
print("Shape of features:", X.shape)
print("Shape of target variable:", y.shape)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# ...

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston_df = boston()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 boston_df = boston()
#
# TypeError: 'Bunch' object is not callable

# %%
boston.DESCR
# Out:
# "**Author**:   \n**Source**: Unknown - Date unknown  \n**Please cite**:   \n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\nVariables in order:\nCRIM     per capita crime rate by town\nZN       proportion of residential land zoned for lots over 25,000 sq.ft.\nINDUS    proportion of non-retail business acres per town\nCHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\nNOX      nitric oxides concentration (parts per 10 million)\nRM       average number of rooms per dwelling\nAGE      proportion of owner-occupied units built prior to 1940\nDIS      weighted distances to five Boston employment centres\nRAD      index of accessibility to radial highways\nTAX      full-value pro
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
print(boston.DESCR )
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# ...

# %%
print(boston.target)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
print(boston.feature_names)
# Out:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# %%
dataset = pd.DataFrame(boston.data)

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   1.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   2.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   2.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   3.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   3.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   1.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   1.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   1.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   1.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   1.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
print(boston.target)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
dataset['price'] = boston.target

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    category
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    category
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: category(2), float64(12)
# memory usage: 49.0 KB

# %%
 dataset.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT       price
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %%
 dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583  0.625505  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.311948 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.595129  0.763651 -0.391676  0.644779
# CHAS     0.625505 -0.311948  0.595129  1.000000  0.611441 -0.209847  0.456022
# NOX      0.420972 -0.516604  0.763651  0.611441  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676 -0.209847 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.456022  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.494588 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129  1.000000  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760  0.910228  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248  0.464741  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns 
sns.pairplot(dataset)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.scatter(dataset['CRIM'],dataset['price'])

# %%
dataset
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
a=5

# %%
a
# Out:
# 5

# %%
plt.scatter(dataset['CHAS'],dataset['price'])

# %%
sns.regplot(x="CHAS",y="price",data = dataset)
# Out:
# <Axes: xlabel='CHAS', ylabel='price'>

# %%
print("hello")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# Convert 'CHAS' column back to numeric (float) data type
dataset['CHAS'] = dataset['RAD'].astype('float')

# Plot regression line using sns.regplot
sns.regplot(x="CHAS", y="price", data=dataset)
plt.xlabel('CHAS')
plt.ylabel('Price')
plt.title('Regression Plot of CHAS vs Price')
plt.show()

# %%
sns.regplot(x="PTRATIO",y="price",data = dataset)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='price'>

# %%
x= dataset.iloc[:,:-1]
y= dataset.iloc[:,-1]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   1.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   2.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   2.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   3.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   3.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B
# 0     15.3  396.90
# 1     17.8  396.90
# 2     17.8  392.83
# 3     18.7  394.63
# 4     18.7  396.90

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42 )

# %%
X_train
# Out:
#          CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 5     0.02985   0.0   2.18    0  0.458  6.430  58.7  6.0622   3  222.0
# 116   0.13158   0.0  10.01    0  0.547  6.176  72.5  2.7301   6  432.0
# 45    0.17142   0.0   6.91    0  0.448  5.682  33.8  5.1004   3  233.0
# 16    1.05393   0.0   8.14    0  0.538  5.935  29.3  4.4986   4  307.0
# 468  15.57570   0.0  18.10    0  0.580  5.926  71.0  2.9084  24  666.0
# ..        ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 106   0.17120   0.0   8.56    0  0.520  5.836  91.9  2.2110   5  384.0
# 270   0.29916  20.0   6.96    0  0.464  5.856  42.1  4.4290   3  223.0
# 348   0.01501  80.0   2.01    0  0.435  6.635  29.7  8.3440   4  280.0
# 435  11.16040   0.0  18.10    0  0.740  6.629  94.6  2.1247  24  666.0
# 102   0.22876   0.0   8.56    0  0.520  6.405  85.4  2.7147   5  384.0
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# ...

# %%
X_test
# Out:
# array([[-0.46684151, -0.52749891, -1.75430529, ..., -8.44094644,
#         -4.13918731, -1.8159044 ],
#        [-0.467354  , -0.44902113, -1.70514771, ..., -8.24404657,
#         -4.1390015 , -1.9251358 ],
#        [-0.46663907, -0.52749891, -1.26085482, ..., -7.7517969 ,
#         -4.13990268, -1.63689177],
#        ...,
#        [-0.46053112, -0.52749891, -1.7095219 , ..., -8.28342654,
#         -4.14097905, -1.90332917],
#        [-0.38723778, -0.52749891, -1.46165105, ..., -7.73210691,
#         -4.1783813 , -1.67356656],
#        [-0.32424582, -0.52749891, -1.46165105, ..., -7.73210691,
#         -4.14011371, -1.66920524]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_train
# Out:
#          CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 5     0.02985   0.0   2.18    0  0.458  6.430  58.7  6.0622   3  222.0
# 116   0.13158   0.0  10.01    0  0.547  6.176  72.5  2.7301   6  432.0
# 45    0.17142   0.0   6.91    0  0.448  5.682  33.8  5.1004   3  233.0
# 16    1.05393   0.0   8.14    0  0.538  5.935  29.3  4.4986   4  307.0
# 468  15.57570   0.0  18.10    0  0.580  5.926  71.0  2.9084  24  666.0
# ..        ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 106   0.17120   0.0   8.56    0  0.520  5.836  91.9  2.2110   5  384.0
# 270   0.29916  20.0   6.96    0  0.464  5.856  42.1  4.4290   3  223.0
# 348   0.01501  80.0   2.01    0  0.435  6.635  29.7  8.3440   4  280.0
# 435  11.16040   0.0  18.10    0  0.740  6.629  94.6  2.1247  24  666.0
# 102   0.22876   0.0   8.56    0  0.520  6.405  85.4  2.7147   5  384.0
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# ...

# %%
# Assuming 'df' is your DataFrame containing the 'RAD' column

# Convert 'RAD' column from category to float
dataset['RAD'] = dataset['RAD'].astype(float)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 y_train
#
# NameError: name 'y_train' is not defined

# %%
print(regression.coef_)
# Out:
# [-4.06124159e-15  6.31111379e-15 -3.85405059e-15 -5.67374029e-17
#  -1.29109219e-15 -1.58279424e-16  2.55248731e-16  3.24230724e-15
#   1.62864006e-15 -6.73400805e-15  1.38170555e-16  3.98663434e-16
#   7.10234960e+00]

# %%
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
print(regression.intercept_)
# Out:
# 12.421129943502825
